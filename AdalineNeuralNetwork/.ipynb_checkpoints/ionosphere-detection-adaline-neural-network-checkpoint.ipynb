# %% [markdown]
# # Ionosphere Detection using Adaline Neural Network
#
# #### Author 1
# - **Name:** João Pedro Fernandes de Aquino
# - **GitHub:** https://github.com/Joaof14
#
# #### Author 2
# - **Name:** Anderson Carlos da Silva Morais
# - **GitHub:** https://github.com/AndersonCSM
#
# <details>
#   <summary style="font-size: 18px; font-weight: bold;"> > Sumário do Projeto  (PT-BR)</summary>
#
# O monitoramento contínuo da ionosfera é crucial para a confiabilidade de sistemas de telecomunicações, navegação GPS e para a previsão de tempestades geomagnéticas. Radares de alta frequência (HF) emitem pulsos e analisam os sinais refletidos para verificar a existência de estruturas eletrônicas coerentes na ionosfera. O Brasil ocupa posição estratégica e desafiadora, situado sobre a Anomalia de Ionização Equatorial, onde a ionosfera apresenta irregularidades intensas e fenômenos como as bolhas de plasma – fatores que afetam diretamente o desempenho de sinais de comunicação e posicionamento. Este projeto utiliza o dataset Ionosphere (UCI Machine Learning Repository), com 351 retornos de radar e 34 atributos contínuos provenientes de autocorrelação de pulsos. O objetivo é construir uma rede Adaline para classificar automaticamente os retornos em “good” (estrutura ionosférica detectada, +1) ou “bad” (ausência de estrutura coerente, –1), contribuindo para sistemas de alerta e diagnóstico da ionosfera.
#
#   ...
# </details>
#
# <details>
#   <summary style="font-size: 18px; font-weight: bold;">>Project Summary (EN-US)</summary>
#     Continuous monitoring of the ionosphere is crucial for the reliability of telecommunications systems, GPS navigation, and the forecasting of geomagnetic storms. High-frequency (HF) radars transmit pulses and analyze the reflected signals to detect coherent electronic structures in the ionosphere. Brazil occupies a strategic and challenging position, situated over the Equatorial Ionization Anomaly, where the ionosphere exhibits intense irregularities and phenomena such as plasma bubbles—factors that directly affect the performance of communication and positioning signals. This project uses the Ionosphere dataset (UCI Machine Learning Repository), with 351 radar returns and 34 continuous attributes derived from pulse autocorrelation. The goal is to build an Adaline network to automatically classify the returns as “good” (ionospheric structure detected, +1) or “bad” (absence of coherent structure, –1), contributing to ionospheric warning and diagnostic systems.
#
#
#   ...
# </details>

# %% [markdown]
# ## Project Steps
# 1. Data exploration and quality checks;
# 2. Validate modeling assumptions;
# 3. Feature selection;
# 4. Normalization or scaling and Data split;
# 5. Model fitting (adjustment);
# 6. Assessment;
# 7. Coefficient or feature-importance analysis;
# 8. Residual/error analysis;
# 9.  Report.

# %% [markdown]
# <details>
#   <summary style="font-size: 1.5em; font-weight: bold;"> Etapa 1: Exploração e Verificação da Qualidade dos Dados – Ionosphere </summary>
#
#
# ### 1. Obter e inspecionar o dataset
# - Carregar o dataset diretamente do repositório UCI (via `ucimlrepo` ou baixando os arquivos `ionosphere.data` e `ionosphere.names`).
# - Criar um DataFrame com as 34 features e a coluna `class`.
# - Utilizar `df.info()` para verificar:
#   - 351 instâncias e 35 colunas (34 preditores + target).
#   - Tipos de dados – todos os preditores devem ser numéricos (`float64` ou `int64`); o target é categórico (`object`).
# - Utilizar `df.head()` e `df.describe()` para um resumo estatístico inicial.
#
# ### 2. Recodificar o target
# - O target original possuir os valores `'g'` (good) e `'b'` (bad).
# - Converter para bipolar: `+1` para `'g'` e `-1` para `'b'`.
# - Confirmar as quantidades: 225 good (+1) e 126 bad (−1).
#
# ### 3. Verificar a qualidade dos dados
# - **Valores ausentes:** Verificar com `df.isnull().sum()`. O conjunto Ionosphere normalmente não possuir valores ausentes. Caso exista algum, decidir o tratamento (imputação ou remoção).
# - **Atributos constantes ou quase constantes:** Calcular o desvio padrão de cada preditor; se algum tiver `std ≈ 0`, remover antes do treinamento (não contribuiria para a classificação e causaria divisão por zero na padronização).
# - **Duplicatas:** `df.duplicated().sum()`. Remover registros duplicados, se houver.
#
# ### 4. Análise univariada
# - Para cada um dos 34 atributos:
#   - Plotar **histogramas** para observar a distribuição.
#   - Plotar **boxplots** para identificar outliers severos.
# - Como todos os atributos são contínuos, essas visualizações ajudar a decidir se uma normalização robusta seria necessária (presença de outliers) – embora o enunciado já peça padronização Z‑score, uma análise prévia reforçar a justificativa.
#
# ### 5. Análise bivariada / multivariada
# - **Correlação entre preditores:** Computar a matriz de correlação de Pearson (`df.iloc[:, :-1].corr()`). Utilizar um mapa de calor para identificar pares altamente correlacionados (ex.: > 0.9). Isso poder indicar redundância – que para a Adaline não quebrar a solução, mas poder dificultar a interpretação.
# - **Correlação preditor–target:** Como o target é bipolar (+1/−1), correlações de Pearson entre cada feature e o target também ser válidas. Criar um gráfico de barras com essas correlações para ver quais features individualmente mais se alinhar com a classe.
# - **Boxplots por classe:** Para as features mais correlacionadas, plotar boxplots separados por classe (good vs bad) – ajudar a visualizar o poder discriminativo.
#
# ### 6. Documentar as evidências
# Ao final desta etapa, produzir:
# - Um resumo da qualidade dos dados (sem missings, sem constantes, presença ou não de outliers).
# - A lista de atributos que eventualmente serem removidos (se houver constantes).
# - Matriz de correlação comentada.
# - Histogramas e boxplots salvos para o relatório.
#   ...
# </details>
#
# <details>
#   <summary style="font-size: 1.5em; font-weight: bold;">Step 1: Data Exploration and Quality Checks – Ionosphere (EN-US)</summary>
#
#
#
# ### 1. Obtain and inspect the dataset
# - Load the dataset directly from the UCI repository (via `ucimlrepo` or by downloading `ionosphere.data` and `ionosphere.names`).
# - Create a DataFrame with the 34 features and the `class` column.
# - Use `df.info()` to check:
#   - 351 instances and 35 columns (34 predictors + target).
#   - Data types – all predictors should be numeric (`float64` or `int64`); the target is categorical (`object`).
# - Use `df.head()` and `df.describe()` for an initial statistical summary.
#
# ### 2. Recode the target
# - The original target has values `'g'` (good) and `'b'` (bad).
# - Convert to bipolar: `+1` for `'g'` and `-1` for `'b'`.
# - Confirm the counts: 225 good (+1) and 126 bad (−1).
#
# ### 3. Check data quality
# - **Missing values:** Check with `df.isnull().sum()`. The Ionosphere dataset typically does not have missing values. If any exist, decide on a treatment (imputation or removal).
# - **Constant or near‑constant features:** Calculate the standard deviation of each predictor; if any has `std ≈ 0`, remove it before training (it would not contribute to classification and would cause division by zero during standardization).
# - **Duplicates:** `df.duplicated().sum()`. Remove duplicate records, if any.
#
# ### 4. Univariate analysis
# - For each of the 34 attributes:
#   - Plot **histograms** to observe the distribution.
#   - Plot **boxplots** to detect severe outliers.
# - Since all attributes are continuous, these visualizations help decide whether a robust normalization is needed (presence of outliers) – even though the assignment already requires Z‑score standardization, a preliminary analysis reinforces the justification.
#
# ### 5. Bivariate / multivariate analysis
# - **Correlation between predictors:** Compute the Pearson correlation matrix (`df.iloc[:, :-1].corr()`). Use a heatmap to identify highly correlated pairs (e.g., > 0.9). This may indicate redundancy – which does not break the Adaline solution but can hinder interpretation.
# - **Predictor–target correlation:** Since the target is bipolar (+1/−1), Pearson correlations between each feature and the target are also valid. Create a bar chart with these correlations to see which features individually align most with the class.
# - **Boxplots by class:** For the most correlated features, plot separate boxplots by class (good vs bad) – this helps visualize discriminative power.
#
# ### 6. Document the evidence
# At the end of this step, produce:
# - A summary of data quality (no missing values, no constants, presence/absence of outliers).
# - A list of attributes to be removed (if any constants are found).
# - An annotated correlation matrix.
# - Histograms and boxplots saved for the report.
#   ...
# </details>

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
# sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    roc_curve,
    auc,
    classification_report,
)

# %%
df = pd.read_csv("data/p03_winequality-red.csv", sep=";")

# %%
print(f"Dataset shape: {df.shape}")
print(f"\nFirst rows of the dataset:")
df.head(10)
# Out:
# Dataset shape: (1599, 12)
#
# First rows of the dataset:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### 1.1 Inspeção Inicial (Initial inspection)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### 1.2 Recodificar o Target

# %%
df["target"] = pd.cut(
df["quality"],
bins=[0, 5, 7, 10],
labels=[0, 1, 2], # - O ruim, 1 - médio, 2 - bom
include_lowest=True
).astype(int)

df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'target'],
#       dtype='object')

# %%
df = df.drop(columns=["quality"])
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'target'],
#       dtype='object')

# %%
X = df.drop(columns=["target"])
y = df["target"]

# %% [markdown]
# ### 1.2 Recodificar o Target

# %%
# Verificar balanceamento do target
print("Balanceamento de classes (target):")
print(df["target"].value_counts().sort_index())
print("\nProporção (%):")
print(df["target"].value_counts(normalize=True).sort_index() * 100)
# Out:
# Balanceamento de classes (target):
# target
# 0    744
# 1    837
# 2     18
# Name: count, dtype: int64
#
# Proporção (%):
# target
# 0    46.529081
# 1    52.345216
# 2     1.125704
# Name: proportion, dtype: float64

# %%
# Visualizar distribuição
fig, ax = plt.subplots(figsize=(8, 5))
df["target"].value_counts().sort_index().plot(kind="bar", ax=ax, color="steelblue")
ax.set_title("Balanceamento de Classes (Qualidade do Vinho)", fontsize=12)
ax.set_xlabel("Classe")
ax.set_ylabel("Frequência")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3 Verificar a Qualidade dos dados
#
# Etapa essencial para auxiliar no processo de normalização. pois diferentes escalas entre variáveis -> Normalização OBRIGATÓRIA para KNN

# %%
# Listar todas as colunas numéricas (excluindo quality e target)
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_cols = [col for col in numeric_cols if col not in ["quality", "target"]]

print(f"Total de features numéricas: {len(numeric_cols)}")
print(f"Colunas: {numeric_cols}")

# Boxplots para ver escala - KNN é sensível a escala (grade dinâmica)
ncols = 3
nrows = int(np.ceil(len(numeric_cols) / ncols))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 3*nrows))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    sns.boxplot(y=df[col], ax=axes[i], color="lightblue")
    axes[i].set_title(f"{col}", fontsize=10)
    axes[i].set_ylabel("Valor")

# Remover subplots não utilizados
for j in range(len(numeric_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# Total de features numéricas: 11
# Colunas: ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']

# %% [markdown]
# ### 1.4 Detecção de Outliers (Afetam Distância no KNN) - Outlier Detection
#  Outliers podem dominar distâncias -> Considere normalizar ou usar métrica ponderada
#
# obs:
# IQR = Interquartile Range (Amplitude Interquartil)
#
# É a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1):

# %%
# Função para quantificar outliers usando IQR
def count_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    return len(outliers), (lower, upper)

print("Quantificação de Outliers (IQR 1.5x):\n")
outlier_summary = []
for col in numeric_cols:
    count, (lower, upper) = count_outliers_iqr(df, col)
    pct = (count / len(df)) * 100
    outlier_summary.append({"Feature": col, "Outliers": count, "Percentual": f"{pct:.2f}%"})
    print(f"{col:20s}: {count:3d} outliers ({pct:.2f}%)")

df_outliers = pd.DataFrame(outlier_summary)
# Out:
# Quantificação de Outliers (IQR 1.5x):
#
# fixed acidity       :  49 outliers (3.06%)
# volatile acidity    :  19 outliers (1.19%)
# citric acid         :   1 outliers (0.06%)
# residual sugar      : 155 outliers (9.69%)
# chlorides           : 112 outliers (7.00%)
# free sulfur dioxide :  30 outliers (1.88%)
# total sulfur dioxide:  55 outliers (3.44%)
# density             :  45 outliers (2.81%)
# pH                  :  35 outliers (2.19%)
# sulphates           :  59 outliers (3.69%)
# alcohol             :  13 outliers (0.81%)

# %% [markdown]
# ### 1.5 Matriz de Correlação - Correlation Matrix
#
# Objetivo: detectar redundância nas features.

# %% [markdown]
# ### 1.7 Resumo data explorer
# 1. BALANCEAMENTO DE CLASSES:
#
#    Ruim: 46.5% | Médio: 52.3% | Bom: 1.1%
#    Classes desbalanceadas -> utilizar stratify no train_test_split
#
# 2. ESCALA DAS VARIÁVEIS:
#
#    11 features numéricas com escalas diferentes
#    NORMALIZAÇÃO OBRIGATÓRIA -> StandardScaler ou MinMaxScaler
#
# 3. OUTLIERS:
#
#    Total: 573 outliers em 11 features
#    Percentual médio: 3.26%
#    Outliers significativos -> normalizar reduz impacto
#
# 4. REDUNDÂNCIA DE FEATURES:
#
#    Nenhuma redundância detectada
#
# 5. TOP 3 FEATURES MAIS CORRELACIONADAS COM QUALIDADE:
#    1. alcohol: 0.451
#    2. sulphates: 0.223
#    3. citric acid: 0.166
#
# 6. PRÓXIMOS PASSOS:
#    1. Normalizar features (StandardScaler)
#    2. Dividir treino/teste com stratify
#    3. Testar k=1,3,5,7,11... com validação cruzada
#    4. Escolher melhor k por acurácia média
#    5. Avaliar no conjunto teste (matriz confusão, F1-score)

# %%
# Identificar índices das amostras erradas
import numpy as np
errors = (y_pred != y_test)
X_test_errors = X_test[errors]
y_test_errors = y_test[errors]
y_pred_errors = y_pred[errors]

# Exibir algumas estatísticas descritivas
print("Média das features nos erros (por classe real):")
for class_val in [0, 1, 2]:
    mask = y_test_errors == class_val
    if mask.sum() > 0:
        print(f"Classe {class_val}: {mask.sum()} erros")
# Out:
# Média das features nos erros (por classe real):
# Classe 0: 36 erros
# Classe 1: 45 erros
# Classe 2: 3 erros
